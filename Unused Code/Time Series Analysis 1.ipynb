# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px

# %%
mydir = "/Users/ptienpasertkij/Documents/RIT/Summer 2021/BANA785/All Data Files/"
wegmansData = mydir + "WegmansData_TimeSeries.txt"
wegmans = pd.read_csv(wegmansData, sep=" ")

# %%
wegmans
# Out:
#            DATE_KEY  CUSTOMER_ID  ITEM_NBR  UNITS  WEIGHT  SALES  \
# 0        2020-02-01         3678     12238      1    0.00   1.86
# 1        2020-02-01         3678     50338      1    0.00   3.23
# 2        2020-02-01         3678     89921      1    0.65   0.93
# 3        2020-02-01         3678    128594      1    0.00   5.03
# 4        2019-10-15          855     12213      3    0.00  10.80
# ...             ...          ...       ...    ...     ...    ...
# 5618230  2020-07-22          644    506594      1    0.65   5.61
# 5618231  2020-07-22          644    776436      1    0.00   7.19
# 5618232  2020-07-22          644    798261      1    0.00   4.31
# 5618233  2020-07-22          644    813430      1    0.00   3.95
# 5618234  2020-07-14         1327     45809      1    0.00  11.51
#
#          HOUSEHOLD_ID  HOH_AGE  HH_INCOME  HH_CHILDREN  ...  month  year  \
# 0                3678       41    50000.0            2  ...      2  2020
# 1                3678       41    50000.0            2  ...      2  2020
# 2                3678       41    50000.0            2  ...      2  2020
# 3                3678       41    50000.0            2  ...      2  2020
# 4                 855       38   125000.0            0  ...     10  2019
# ...               ...      ...        ...          ...  ...    ...   ...
# 5618230           644       56    50000.0            3  ...      7  2020
# 5618231           644       56    50000.0            3  ...      7  2020
# 5618232           644       56    50000.0            3  ...      7  2020
# 5618233           644       56    50000.0            3  ...      7  2020
# 5618234          1327       68    40000.0            2  ...      7  2020
#
#         dayofweek week monthyear weekyear    PPU  WEGMANS_ORGANIC  \
# 0               7    4   2020/02  2020/04   1.86                0
# 1               7    4   2020/02  2020/04   3.23                1
# 2               7    4   2020/02  2020/04   0.93                0
# 3               7    4   2020/02  2020/04   5.03                0
# 4               3   41   2019/10  2019/41   3.60                0
# ...           ...  ...       ...      ...    ...              ...
# 5618230         4   29   2020/07  2020/29   5.61                0
# 5618231         4   29   2020/07  2020/29   7.19                0
# 5618232         4   29   2020/07  2020/29   4.31                0
# 5618233         4   29   2020/07  2020/29   3.95                0
# 5618234         3   28   2020/07  2020/28  11.51                0
#
#          WEGMANS_FAMPACK  IS_BULK
# 0                      1        0
# 1                      1        0
# 2                      0        0
# 3                      0        0
# 4                      0        0
# ...                  ...      ...
# 5618230                0        0
# 5618231                0        0
# 5618232                0        0
# 5618233                0        0
# 5618234                1        0
#
# [5618235 rows x 31 columns]

# %%
wegmans.DATE_KEY = pd.to_datetime(wegmans.DATE_KEY,format='%Y-%m-%d')

# %%
wegmans = wegmans.sort_values(['DATE_KEY','DEPARTMENT_NAME','CATEGORY_NAME'])

# %%
wegmansnew = wegmans.groupby([pd.Grouper(key='DATE_KEY',freq='d'),'DEPARTMENT_NAME', 'CATEGORY_NAME'])['SALES'].sum().reset_index()

# %%
wegmansnew['Yesterday Sales'] = wegmansnew.groupby(['CATEGORY_NAME'])['SALES'].shift()
wegmansnew['Week Ago Sales'] = wegmansnew.groupby(['CATEGORY_NAME'])['SALES'].shift(7)

# %%
wegmansnew['isWeekend'] = (wegmansnew['DATE_KEY'].dt.dayofweek >= 5)

# %%
wegmansnew.isna().sum()
# Out:
# DATE_KEY              0
# DEPARTMENT_NAME       0
# CATEGORY_NAME         0
# SALES                 0
# Yesterday Sales     581
# Week Ago Sales     3996
# isWeekend             0
# dtype: int64

# %%
wegmansnew['Yesterday Sales'].fillna(0, inplace = True)
wegmansnew['Week Ago Sales'].fillna(0, inplace = True)

# %%
wegmansnew
# Out:
#          DATE_KEY  DEPARTMENT_NAME                CATEGORY_NAME  SALES  \
# 0      2019-01-06            ASIAN                    ASIAN HOT   1.43
# 1      2019-01-06            ASIAN               ASIAN PACKAGED  91.42
# 2      2019-01-06         BAKESHOP                       BAGELS  25.26
# 3      2019-01-06         BAKESHOP             BAKESHOP COOKIES  39.06
# 4      2019-01-06         BAKESHOP  BAKESHOP DISTRIBUTION ITEMS  56.65
# ...           ...              ...                          ...    ...
# 300640 2020-12-31            SUSHI           SKINNY ROLLS SUSHI   6.47
# 300641 2020-12-31            SUSHI                 VEGGIE SUSHI  16.52
# 300642 2020-12-31  ULTIMATE COFFEE                    BREAKFAST   6.46
# 300643 2020-12-31  ULTIMATE COFFEE                  COLD DRINKS   2.12
# 300644 2020-12-31   WBRAND & OTHER               W BRAND RETAIL  66.77
#
#         Yesterday Sales  Week Ago Sales  isWeekend
# 0                  0.00            0.00       True
# 1                  0.00            0.00       True
# 2                  0.00            0.00       True
# 3                  0.00            0.00       True
# 4                  0.00            0.00       True
# ...                 ...             ...        ...
# 300640            12.94           11.50      False
# 300641            25.15           25.14      False
# 300642             3.23            3.23      False
# 300643             1.69            4.60      False
# 300644            53.39           76.43      False
#
# [300645 rows x 7 columns]

# %%
from sklearn.ensemble import RandomForestRegressor
from lightgbm import LGBMRegressor

# %%
from sklearn.metrics import mean_squared_error
def rmsle(ytrue, ypred):
    return np.sqrt(mean_squared_error(ytrue, ypred))

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
le.fit(wegmansnew['CATEGORY_NAME'])
wegmansnew['CATCODES'] = le.transform(wegmansnew['CATEGORY_NAME'])

# %%
import datetime
pd.set_option('mode.chained_assignment',None)

start_date = datetime.date(2019,1,7)
end_date = datetime.date(2020,3,1)
delta = datetime.timedelta(days=1)
windowdelta = datetime.timedelta(days=30)
dateidx = start_date

mean_error = []
wegmanspred = pd.DataFrame() 

while dateidx < end_date:
    print(dateidx)
    train = wegmansnew[(wegmansnew['DATE_KEY'] < pd.Timestamp(dateidx)) & (wegmansnew['DATE_KEY'] > pd.Timestamp(dateidx - windowdelta))]
    val = wegmansnew[wegmansnew['DATE_KEY'] == pd.Timestamp(dateidx)]
    
    if val.size > 0:
        xtr, xts = train[['CATCODES','Yesterday Sales','Week Ago Sales','isWeekend']], val[['CATCODES','Yesterday Sales','Week Ago Sales','isWeekend']]
        ytr, yts = train['SALES'].values, val['SALES'].values
    
        mdl = RandomForestRegressor(n_estimators=500, n_jobs=-1, random_state=0)
        mdl.fit(xtr, ytr)

        p = mdl.predict(xts)
    
        val.loc[:, 'Prediction'] = np.round(p)
        wegmanspred = pd.concat([wegmanspred,val])
        error = rmsle(yts, p)
        print('Day %s - Error %.5f' % (str(dateidx), error))
        mean_error.append(error)
    dateidx += delta
print('Mean Error = %.5f' % np.mean(mean_error))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ee8b36eef9af> in <module>
#       1 import datetime
# ----> 2 pd.set_option('mode.chained_assignment',None)
#       3
#       4 start_date = datetime.date(2019,1,7)
#       5 end_date = datetime.date(2020,12,25)
#
# NameError: name 'pd' is not defined

# %%
wegmanspred.to_csv('prepandemic_30daywindow.csv')

# %%
import datetime
pd.set_option('mode.chained_assignment',None)

start_date = datetime.date(2020,3,1)
end_date = datetime.date(2020,12,31)
delta = datetime.timedelta(days=1)
dateidx = start_date

while dateidx <= end_date:
    print(dateidx)
    val = wegmansnew[wegmansnew['DATE_KEY'] == pd.Timestamp(dateidx)] 
    if val.size > 0:
        xts = val[['CATCODES','Yesterday Sales','Week Ago Sales','isWeekend']]
        p = mdl.predict(xts)
        val.loc[:, 'Prediction'] = np.round(p)
        wegmanspred = pd.concat([wegmanspred,val])
    dateidx += delta
# Out:
# 2020-03-01
# 2020-03-02
# 2020-03-03
# 2020-03-04
# 2020-03-05
# 2020-03-06
# 2020-03-07
# 2020-03-08
# 2020-03-09
# 2020-03-10
# 2020-03-11
# 2020-03-12
# 2020-03-13
# 2020-03-14
# 2020-03-15
# 2020-03-16
# 2020-03-17
# 2020-03-18
# 2020-03-19
# 2020-03-20
# 2020-03-21
# 2020-03-22
# 2020-03-23
# 2020-03-24
# 2020-03-25
# 2020-03-26
# 2020-03-27
# 2020-03-28
# 2020-03-29
# 2020-03-30
# 2020-03-31
# 2020-04-01
# 2020-04-02
# 2020-04-03
# 2020-04-04
# 2020-04-05
# 2020-04-06
# 2020-04-07
# 2020-04-08
# 2020-04-09
# 2020-04-10
# 2020-04-11
# 2020-04-12
# 2020-04-13
# 2020-04-14
# 2020-04-15
# 2020-04-16
# 2020-04-17
# 2020-04-18
# 2020-04-19
# 2020-04-20
# 2020-04-21
# 2020-04-22
# 2020-04-23
# 2020-04-24
# 2020-04-25
# 2020-04-26
# 2020-04-27
# 2020-04-28
# 2020-04-29
# 2020-04-30
# 2020-05-01
# 2020-05-02
# 2020-05-03
# 2020-05-04
# 2020-05-05
# 2020-05-06
# 2020-05-07
# 2020-05-08
# 2020-05-09
# 2020-05-10
# 2020-05-11
# 2020-05-12
# 2020-05-13
# 2020-05-14
# 2020-05-15
# 2020-05-16
# 2020-05-17
# 2020-05-18
# 2020-05-19
# 2020-05-20
# 2020-05-21
# 2020-05-22
# 2020-05-23
# 2020-05-24
# 2020-05-25
# 2020-05-26
# 2020-05-27
# 2020-05-28
# 2020-05-29
# 2020-05-30
# 2020-05-31
# 2020-06-01
# 2020-06-02
# 2020-06-03
# 2020-06-04
# 2020-06-05
# 2020-06-06
# 2020-06-07
# 2020-06-08
# 2020-06-09
# 2020-06-10
# 2020-06-11
# 2020-06-12
# 2020-06-13
# 2020-06-14
# 2020-06-15
# 2020-06-16
# 2020-06-17
# 2020-06-18
# 2020-06-19
# 2020-06-20
# 2020-06-21
# 2020-06-22
# 2020-06-23
# 2020-06-24
# 2020-06-25
# 2020-06-26
# 2020-06-27
# 2020-06-28
# 2020-06-29
# 2020-06-30
# 2020-07-01
# 2020-07-02
# 2020-07-03
# 2020-07-04
# 2020-07-05
# 2020-07-06
# 2020-07-07
# 2020-07-08
# 2020-07-09
# 2020-07-10
# 2020-07-11
# 2020-07-12
# 2020-07-13
# 2020-07-14
# 2020-07-15
# 2020-07-16
# 2020-07-17
# 2020-07-18
# 2020-07-19
# 2020-07-20
# 2020-07-21
# 2020-07-22
# 2020-07-23
# 2020-07-24
# 2020-07-25
# 2020-07-26
# 2020-07-27
# 2020-07-28
# 2020-07-29
# 2020-07-30
# 2020-07-31
# 2020-08-01
# 2020-08-02
# 2020-08-03
# 2020-08-04
# 2020-08-05
# 2020-08-06
# 2020-08-07
# 2020-08-08
# 2020-08-09
# 2020-08-10
# 2020-08-11
# 2020-08-12
# 2020-08-13
# 2020-08-14
# 2020-08-15
# 2020-08-16
# 2020-08-17
# 2020-08-18
# 2020-08-19
# 2020-08-20
# 2020-08-21
# 2020-08-22
# 2020-08-23
# 2020-08-24
# 2020-08-25
# 2020-08-26
# 2020-08-27
# 2020-08-28
# 2020-08-29
# 2020-08-30
# 2020-08-31
# 2020-09-01
# 2020-09-02
# 2020-09-03
# 2020-09-04
# 2020-09-05
# 2020-09-06
# 2020-09-07
# 2020-09-08
# 2020-09-09
# 2020-09-10
# 2020-09-11
# 2020-09-12
# 2020-09-13
# 2020-09-14
# 2020-09-15
# 2020-09-16
# 2020-09-17
# 2020-09-18
# 2020-09-19
# 2020-09-20
# 2020-09-21
# 2020-09-22
# 2020-09-23
# 2020-09-24
# 2020-09-25
# 2020-09-26
# 2020-09-27
# 2020-09-28
# 2020-09-29
# 2020-09-30
# 2020-10-01
# 2020-10-02
# 2020-10-03
# 2020-10-04
# 2020-10-05
# 2020-10-06
# 2020-10-07
# 2020-10-08
# 2020-10-09
# 2020-10-10
# 2020-10-11
# 2020-10-12
# 2020-10-13
# 2020-10-14
# 2020-10-15
# 2020-10-16
# 2020-10-17
# 2020-10-18
# 2020-10-19
# 2020-10-20
# 2020-10-21
# 2020-10-22
# 2020-10-23
# 2020-10-24
# 2020-10-25
# 2020-10-26
# 2020-10-27
# 2020-10-28
# 2020-10-29
# 2020-10-30
# 2020-10-31
# 2020-11-01
# 2020-11-02
# 2020-11-03
# 2020-11-04
# 2020-11-05
# 2020-11-06
# 2020-11-07
# 2020-11-08
# 2020-11-09
# 2020-11-10
# 2020-11-11
# 2020-11-12
# 2020-11-13
# 2020-11-14
# 2020-11-15
# 2020-11-16
# 2020-11-17
# 2020-11-18
# 2020-11-19
# 2020-11-20
# 2020-11-21
# 2020-11-22
# 2020-11-23
# 2020-11-24
# 2020-11-25
# 2020-11-26
# 2020-11-27
# 2020-11-28
# 2020-11-29
# 2020-11-30
# 2020-12-01
# 2020-12-02
# 2020-12-03
# 2020-12-04
# 2020-12-05
# 2020-12-06
# 2020-12-07
# 2020-12-08
# 2020-12-09
# 2020-12-10
# 2020-12-11
# 2020-12-12
# 2020-12-13
# 2020-12-14
# 2020-12-15
# 2020-12-16
# 2020-12-17
# 2020-12-18
# 2020-12-19
# 2020-12-20
# 2020-12-21
# 2020-12-22
# 2020-12-23
# 2020-12-24
# 2020-12-25
# 2020-12-26
# 2020-12-27
# 2020-12-28
# 2020-12-29
# 2020-12-30
# 2020-12-31

# %%
wegmanspred.to_csv('2019and2020predictions_30dayswindow.csv')

# %%
import datetime
pd.set_option('mode.chained_assignment',None)

start_date = datetime.date(2019,1,7)
end_date = datetime.date(2020,3,1)
delta = datetime.timedelta(days=1)
windowdelta = datetime.timedelta(days=30)
dateidx = start_date

mean_error_lgbm = []
wegmanspredlgbm = pd.DataFrame() 

while dateidx < end_date:
    print(dateidx)
    train_lgbm = wegmansnew[(wegmansnew['DATE_KEY'] < pd.Timestamp(dateidx)) & (wegmansnew['DATE_KEY'] > pd.Timestamp(dateidx - windowdelta))]
    val_lgbm = wegmansnew[wegmansnew['DATE_KEY'] == pd.Timestamp(dateidx)]
    
    if val_lgbm.size > 0:
        xtr_lgbm, xts_lgbm = train_lgbm[['CATCODES','Yesterday Sales','Week Ago Sales','isWeekend']], val_lgbm[['CATCODES','Yesterday Sales','Week Ago Sales','isWeekend']]
        ytr_lgbm, yts_lgbm = train_lgbm['SALES'].values, val_lgbm['SALES'].values
    
        mdl_lgbm = LGBMRegressor(n_estimators=1000, learning_rate=0.01)
        mdl_lgbm.fit(xtr_lgbm, np.log1p(ytr_lgbm))

        p_lgbm = np.expm1(mdl_lgbm.predict(xts_lgbm))
    
        val_lgbm.loc[:, 'Prediction'] = np.round(p_lgbm)
        wegmanspredlgbm = pd.concat([wegmanspredlgbm,val_lgbm])
        error_lgbm = rmsle(yts_lgbm, p_lgbm)
        print('Day %s - Error %.5f' % (str(dateidx), error_lgbm))
        mean_error_lgbm.append(error_lgbm)
    dateidx += delta
print('Mean Error = %.5f' % np.mean(mean_error_lgbm))
# Out:
# 2019-01-07
# Day 2019-01-07 - Error 81.73828
# 2019-01-08
# Day 2019-01-08 - Error 96.85362
# 2019-01-09
# Day 2019-01-09 - Error 109.58056
# 2019-01-10
# Day 2019-01-10 - Error 54.01500
# 2019-01-11
# Day 2019-01-11 - Error 66.04314
# 2019-01-12
# Day 2019-01-12 - Error 80.75780
# 2019-01-13
# Day 2019-01-13 - Error 111.87561
# 2019-01-14
# Day 2019-01-14 - Error 38.45213
# 2019-01-15
# Day 2019-01-15 - Error 42.44034
# 2019-01-16
# Day 2019-01-16 - Error 216.75677
# 2019-01-17
# Day 2019-01-17 - Error 98.89386
# 2019-01-18
# Day 2019-01-18 - Error 117.67309
# 2019-01-19
# Day 2019-01-19 - Error 66.82850
# 2019-01-20
# Day 2019-01-20 - Error 104.74740
# 2019-01-21
# Day 2019-01-21 - Error 53.95632
# 2019-01-22
# Day 2019-01-22 - Error 103.98016
# 2019-01-23
# Day 2019-01-23 - Error 75.74016
# 2019-01-24
# Day 2019-01-24 - Error 37.07451
# 2019-01-25
# Day 2019-01-25 - Error 38.88396
# 2019-01-26
# Day 2019-01-26 - Error 130.51491
# 2019-01-27
# Day 2019-01-27 - Error 114.09419
# 2019-01-28
# Day 2019-01-28 - Error 45.67551
# 2019-01-29
# Day 2019-01-29 - Error 39.06186
# 2019-01-30
# Day 2019-01-30 - Error 31.36209
# 2019-01-31
# Day 2019-01-31 - Error 42.06949
# 2019-02-01
# Day 2019-02-01 - Error 71.11173
# 2019-02-02
# Day 2019-02-02 - Error 129.22016
# 2019-02-03
# Day 2019-02-03 - Error 62.46255
# 2019-02-04
# Day 2019-02-04 - Error 59.75165
# 2019-02-05
# Day 2019-02-05 - Error 49.37047
# 2019-02-06
# Day 2019-02-06 - Error 20.33011
# 2019-02-07
# Day 2019-02-07 - Error 31.74057
# 2019-02-08
# Day 2019-02-08 - Error 48.81048
# 2019-02-09
# Day 2019-02-09 - Error 39.00968
# 2019-02-10
# Day 2019-02-10 - Error 101.56091
# 2019-02-11
# Day 2019-02-11 - Error 77.31582
# 2019-02-12
# Day 2019-02-12 - Error 31.59134
# 2019-02-13
# Day 2019-02-13 - Error 64.17626
# 2019-02-14
# Day 2019-02-14 - Error 58.15570
# 2019-02-15
# Day 2019-02-15 - Error 34.24711
# 2019-02-16
# Day 2019-02-16 - Error 56.07406
# 2019-02-17
# Day 2019-02-17 - Error 44.81987
# 2019-02-18
# Day 2019-02-18 - Error 63.83472
# 2019-02-19
# Day 2019-02-19 - Error 34.45440
# 2019-02-20
# Day 2019-02-20 - Error 102.72685
# 2019-02-21
# Day 2019-02-21 - Error 28.84833
# 2019-02-22
# Day 2019-02-22 - Error 42.35983
# 2019-02-23
# Day 2019-02-23 - Error 115.52090
# 2019-02-24
# Day 2019-02-24 - Error 61.19621
# 2019-02-25
# Day 2019-02-25 - Error 56.62794
# 2019-02-26
# Day 2019-02-26 - Error 43.46895
# 2019-02-27
# Day 2019-02-27 - Error 93.83246
# 2019-02-28
# Day 2019-02-28 - Error 59.99565
# 2019-03-01
# Day 2019-03-01 - Error 46.83483
# 2019-03-02
# Day 2019-03-02 - Error 34.59735
# 2019-03-03
# Day 2019-03-03 - Error 58.21551
# 2019-03-04
# Day 2019-03-04 - Error 58.75273
# 2019-03-05
# Day 2019-03-05 - Error 39.26764
# 2019-03-06
# Day 2019-03-06 - Error 24.47576
# 2019-03-07
# Day 2019-03-07 - Error 32.19614
# 2019-03-08
# Day 2019-03-08 - Error 39.33566
# 2019-03-09
# Day 2019-03-09 - Error 47.59980
# 2019-03-10
# Day 2019-03-10 - Error 35.05288
# 2019-03-11
# Day 2019-03-11 - Error 48.56069
# 2019-03-12
# Day 2019-03-12 - Error 96.42906
# 2019-03-13
# Day 2019-03-13 - Error 26.29761
# 2019-03-14
# Day 2019-03-14 - Error 24.84390
# 2019-03-15
# Day 2019-03-15 - Error 33.30921
# 2019-03-16
# Day 2019-03-16 - Error 42.54310
# 2019-03-17
# Day 2019-03-17 - Error 47.09989
# 2019-03-18
# Day 2019-03-18 - Error 68.39575
# 2019-03-19
# Day 2019-03-19 - Error 27.40402
# 2019-03-20
# Day 2019-03-20 - Error 52.01468
# 2019-03-21
# Day 2019-03-21 - Error 49.01241
# 2019-03-22
# Day 2019-03-22 - Error 28.02249
# 2019-03-23
# Day 2019-03-23 - Error 70.04902
# 2019-03-24
# Day 2019-03-24 - Error 59.03593
# 2019-03-25
# Day 2019-03-25 - Error 43.92012
# 2019-03-26
# Day 2019-03-26 - Error 23.92769
# 2019-03-27
# Day 2019-03-27 - Error 18.92404
# 2019-03-28
# Day 2019-03-28 - Error 83.12268
# 2019-03-29
# Day 2019-03-29 - Error 31.42465
# 2019-03-30
# Day 2019-03-30 - Error 37.08376
# 2019-03-31
# Day 2019-03-31 - Error 42.18373
# 2019-04-01
# Day 2019-04-01 - Error 29.78769
# 2019-04-02
# Day 2019-04-02 - Error 42.93159
# 2019-04-03
# Day 2019-04-03 - Error 62.44979
# 2019-04-04
# Day 2019-04-04 - Error 40.25042
# 2019-04-05
# Day 2019-04-05 - Error 57.57800
# 2019-04-06
# Day 2019-04-06 - Error 84.18856
# 2019-04-07
# Day 2019-04-07 - Error 127.85647
# 2019-04-08
# Day 2019-04-08 - Error 29.68561
# 2019-04-09
# Day 2019-04-09 - Error 24.17746
# 2019-04-10
# Day 2019-04-10 - Error 55.35562
# 2019-04-11
# Day 2019-04-11 - Error 27.60575
# 2019-04-12
# Day 2019-04-12 - Error 43.29208
# 2019-04-13
# Day 2019-04-13 - Error 44.76819
# 2019-04-14
# Day 2019-04-14 - Error 35.63063
# 2019-04-15
# Day 2019-04-15 - Error 56.57331
# 2019-04-16
# Day 2019-04-16 - Error 34.95698
# 2019-04-17
# Day 2019-04-17 - Error 33.81936
# 2019-04-18
# Day 2019-04-18 - Error 41.90809
# 2019-04-19
# Day 2019-04-19 - Error 58.43518
# 2019-04-20
# Day 2019-04-20 - Error 156.78023
# 2019-04-21
# Day 2019-04-21 - Error 87.77240
# 2019-04-22
# Day 2019-04-22 - Error 65.30520
# 2019-04-23
# Day 2019-04-23 - Error 140.10758
# 2019-04-24
# Day 2019-04-24 - Error 88.63121
# 2019-04-25
# Day 2019-04-25 - Error 23.88654
# 2019-04-26
# Day 2019-04-26 - Error 82.29034
# 2019-04-27
# Day 2019-04-27 - Error 89.37473
# 2019-04-28
# Day 2019-04-28 - Error 56.70478
# 2019-04-29
# Day 2019-04-29 - Error 81.76282
# 2019-04-30
# Day 2019-04-30 - Error 26.02364
# 2019-05-01
# Day 2019-05-01 - Error 52.04589
# 2019-05-02
# Day 2019-05-02 - Error 66.24235
# 2019-05-03
# Day 2019-05-03 - Error 76.90501
# 2019-05-04
# Day 2019-05-04 - Error 50.05011
# 2019-05-05
# Day 2019-05-05 - Error 50.18533
# 2019-05-06
# Day 2019-05-06 - Error 41.68391
# 2019-05-07
# Day 2019-05-07 - Error 33.92499
# 2019-05-08
# Day 2019-05-08 - Error 28.30699
# 2019-05-09
# Day 2019-05-09 - Error 45.67526
# 2019-05-10
# Day 2019-05-10 - Error 42.12138
# 2019-05-11
# Day 2019-05-11 - Error 173.47580
# 2019-05-12
# Day 2019-05-12 - Error 78.17799
# 2019-05-13
# Day 2019-05-13 - Error 35.75719
# 2019-05-14
# Day 2019-05-14 - Error 36.44070
# 2019-05-15
# Day 2019-05-15 - Error 37.81317
# 2019-05-16
# Day 2019-05-16 - Error 39.40832
# 2019-05-17
# Day 2019-05-17 - Error 41.85009
# 2019-05-18
# Day 2019-05-18 - Error 35.75381
# 2019-05-19
# Day 2019-05-19 - Error 50.61055
# 2019-05-20
# Day 2019-05-20 - Error 46.95994
# 2019-05-21
# Day 2019-05-21 - Error 38.92090
# 2019-05-22
# Day 2019-05-22 - Error 67.77246
# 2019-05-23
# Day 2019-05-23 - Error 37.38986
# 2019-05-24
# Day 2019-05-24 - Error 56.45282
# 2019-05-25
# Day 2019-05-25 - Error 80.32781
# 2019-05-26
# Day 2019-05-26 - Error 72.28091
# 2019-05-27
# Day 2019-05-27 - Error 56.97099
# 2019-05-28
# Day 2019-05-28 - Error 77.94400
# 2019-05-29
# Day 2019-05-29 - Error 26.07784
# 2019-05-30
# Day 2019-05-30 - Error 30.51850
# 2019-05-31
# Day 2019-05-31 - Error 92.25660
# 2019-06-01
# Day 2019-06-01 - Error 35.25167
# 2019-06-02
# Day 2019-06-02 - Error 53.92190
# 2019-06-03
# Day 2019-06-03 - Error 105.94575
# 2019-06-04
# Day 2019-06-04 - Error 26.43254
# 2019-06-05
# Day 2019-06-05 - Error 31.32238
# 2019-06-06
# Day 2019-06-06 - Error 31.92726
# 2019-06-07
# Day 2019-06-07 - Error 37.32735
# 2019-06-08
# Day 2019-06-08 - Error 45.89912
# 2019-06-09
# Day 2019-06-09 - Error 41.97172
# 2019-06-10
# Day 2019-06-10 - Error 184.33811
# 2019-06-11
# Day 2019-06-11 - Error 25.42929
# 2019-06-12
# Day 2019-06-12 - Error 39.65027
# 2019-06-13
# Day 2019-06-13 - Error 26.19293
# 2019-06-14
# Day 2019-06-14 - Error 60.25616
# 2019-06-15
# Day 2019-06-15 - Error 56.06521
# 2019-06-16
# Day 2019-06-16 - Error 67.11768
# 2019-06-17
# Day 2019-06-17 - Error 34.35807
# 2019-06-18
# Day 2019-06-18 - Error 63.64515
# 2019-06-19
# Day 2019-06-19 - Error 73.67315
# 2019-06-20
# Day 2019-06-20 - Error 28.75991
# 2019-06-21
# Day 2019-06-21 - Error 35.88964
# 2019-06-22
# Day 2019-06-22 - Error 133.29907
# 2019-06-23
# Day 2019-06-23 - Error 67.08044
# 2019-06-24
# Day 2019-06-24 - Error 47.05894
# 2019-06-25
# Day 2019-06-25 - Error 22.27070
# 2019-06-26
# Day 2019-06-26 - Error 32.28866
# 2019-06-27
# Day 2019-06-27 - Error 44.87820
# 2019-06-28
# Day 2019-06-28 - Error 35.04395
# 2019-06-29
# Day 2019-06-29 - Error 36.44434
# 2019-06-30
# Day 2019-06-30 - Error 56.00417
# 2019-07-01
# Day 2019-07-01 - Error 47.70574
# 2019-07-02
# Day 2019-07-02 - Error 44.44947
# 2019-07-03
# Day 2019-07-03 - Error 79.26386
# 2019-07-04
# Day 2019-07-04 - Error 47.04079
# 2019-07-05
# Day 2019-07-05 - Error 47.04859
# 2019-07-06
# Day 2019-07-06 - Error 32.28021
# 2019-07-07
# Day 2019-07-07 - Error 36.02755
# 2019-07-08
# Day 2019-07-08 - Error 30.34306
# 2019-07-09
# Day 2019-07-09 - Error 125.13010
# 2019-07-10
# Day 2019-07-10 - Error 41.98663
# 2019-07-11
# Day 2019-07-11 - Error 51.06615
# 2019-07-12
# Day 2019-07-12 - Error 96.10230
# 2019-07-13
# Day 2019-07-13 - Error 41.78251
# 2019-07-14
# Day 2019-07-14 - Error 42.80121
# 2019-07-15
# Day 2019-07-15 - Error 30.99554
# 2019-07-16
# Day 2019-07-16 - Error 22.35699
# 2019-07-17
# Day 2019-07-17 - Error 37.29818
# 2019-07-18
# Day 2019-07-18 - Error 30.33204
# 2019-07-19
# Day 2019-07-19 - Error 30.24017
# 2019-07-20
# Day 2019-07-20 - Error 46.03224
# 2019-07-21
# Day 2019-07-21 - Error 56.29518
# 2019-07-22
# Day 2019-07-22 - Error 43.86206
# 2019-07-23
# Day 2019-07-23 - Error 32.80375
# 2019-07-24
# Day 2019-07-24 - Error 27.88324
# 2019-07-25
# Day 2019-07-25 - Error 76.44637
# 2019-07-26
# Day 2019-07-26 - Error 25.52559
# 2019-07-27
# Day 2019-07-27 - Error 83.14132
# 2019-07-28
# Day 2019-07-28 - Error 36.28165
# 2019-07-29
# Day 2019-07-29 - Error 176.41642
# 2019-07-30
# Day 2019-07-30 - Error 35.51540
# 2019-07-31
# Day 2019-07-31 - Error 480.44821
# 2019-08-01
# Day 2019-08-01 - Error 46.67527
# 2019-08-02
# Day 2019-08-02 - Error 43.82592
# 2019-08-03
# Day 2019-08-03 - Error 32.43759
# 2019-08-04
# Day 2019-08-04 - Error 38.75395
# 2019-08-05
# Day 2019-08-05 - Error 44.86037
# 2019-08-06
# Day 2019-08-06 - Error 40.49819
# 2019-08-07
# Day 2019-08-07 - Error 29.05930
# 2019-08-08
# Day 2019-08-08 - Error 32.96066
# 2019-08-09
# Day 2019-08-09 - Error 30.31009
# 2019-08-10
# Day 2019-08-10 - Error 140.55360
# 2019-08-11
# Day 2019-08-11 - Error 75.07653
# 2019-08-12
# Day 2019-08-12 - Error 46.97453
# 2019-08-13
# Day 2019-08-13 - Error 24.32243
# 2019-08-14
# Day 2019-08-14 - Error 35.85764
# 2019-08-15
# Day 2019-08-15 - Error 27.56148
# 2019-08-16
# Day 2019-08-16 - Error 68.01676
# 2019-08-17
# Day 2019-08-17 - Error 39.47254
# 2019-08-18
# Day 2019-08-18 - Error 51.71350
# 2019-08-19
# Day 2019-08-19 - Error 37.74282
# 2019-08-20
# Day 2019-08-20 - Error 72.64979
# 2019-08-21
# Day 2019-08-21 - Error 35.72386
# 2019-08-22
# Day 2019-08-22 - Error 29.41461
# 2019-08-23
# Day 2019-08-23 - Error 37.15466
# 2019-08-24
# Day 2019-08-24 - Error 57.75153
# 2019-08-25
# Day 2019-08-25 - Error 73.70103
# 2019-08-26
# Day 2019-08-26 - Error 41.93291
# 2019-08-27
# Day 2019-08-27 - Error 27.67058
# 2019-08-28
# Day 2019-08-28 - Error 72.50423
# 2019-08-29
# Day 2019-08-29 - Error 47.65161
# 2019-08-30
# Day 2019-08-30 - Error 67.47436
# 2019-08-31
# Day 2019-08-31 - Error 47.31291
# 2019-09-01
# Day 2019-09-01 - Error 61.87910
# 2019-09-02
# Day 2019-09-02 - Error 52.24396
# 2019-09-03
# Day 2019-09-03 - Error 52.99818
# 2019-09-04
# Day 2019-09-04 - Error 30.49822
# 2019-09-05
# Day 2019-09-05 - Error 28.19389
# 2019-09-06
# Day 2019-09-06 - Error 25.21876
# 2019-09-07
# Day 2019-09-07 - Error 73.27443
# 2019-09-08
# Day 2019-09-08 - Error 51.56790
# 2019-09-09
# Day 2019-09-09 - Error 70.01944
# 2019-09-10
# Day 2019-09-10 - Error 28.16353
# 2019-09-11
# Day 2019-09-11 - Error 33.09981
# 2019-09-12
# Day 2019-09-12 - Error 36.47954
# 2019-09-13
# Day 2019-09-13 - Error 33.10946
# 2019-09-14
# Day 2019-09-14 - Error 33.92211
# 2019-09-15
# Day 2019-09-15 - Error 42.32289
# 2019-09-16
# Day 2019-09-16 - Error 23.47302
# 2019-09-17
# Day 2019-09-17 - Error 138.76382
# 2019-09-18
# Day 2019-09-18 - Error 29.29098
# 2019-09-19
# Day 2019-09-19 - Error 24.57395
# 2019-09-20
# Day 2019-09-20 - Error 32.53181
# 2019-09-21
# Day 2019-09-21 - Error 66.94893
# 2019-09-22
# Day 2019-09-22 - Error 40.67935
# 2019-09-23
# Day 2019-09-23 - Error 28.77908
# 2019-09-24
# Day 2019-09-24 - Error 32.07155
# 2019-09-25
# Day 2019-09-25 - Error 40.21386
# 2019-09-26
# Day 2019-09-26 - Error 55.65765
# 2019-09-27
# Day 2019-09-27 - Error 35.96725
# 2019-09-28
# Day 2019-09-28 - Error 36.51276
# 2019-09-29
# Day 2019-09-29 - Error 130.44015
# 2019-09-30
# Day 2019-09-30 - Error 28.06688
# 2019-10-01
# Day 2019-10-01 - Error 23.17727
# 2019-10-02
# Day 2019-10-02 - Error 25.03646
# 2019-10-03
# Day 2019-10-03 - Error 30.79206
# 2019-10-04
# Day 2019-10-04 - Error 36.26132
# 2019-10-05
# Day 2019-10-05 - Error 33.60684
# 2019-10-06
# Day 2019-10-06 - Error 41.84324
# 2019-10-07
# Day 2019-10-07 - Error 30.28277
# 2019-10-08
# Day 2019-10-08 - Error 30.49516
# 2019-10-09
# Day 2019-10-09 - Error 24.61745
# 2019-10-10
# Day 2019-10-10 - Error 29.80597
# 2019-10-11
# Day 2019-10-11 - Error 31.05226
# 2019-10-12
# Day 2019-10-12 - Error 37.47619
# 2019-10-13
# Day 2019-10-13 - Error 42.41289
# 2019-10-14
# Day 2019-10-14 - Error 49.04274
# 2019-10-15
# Day 2019-10-15 - Error 82.58772
# 2019-10-16
# Day 2019-10-16 - Error 30.25930
# 2019-10-17
# Day 2019-10-17 - Error 25.30419
# 2019-10-18
# Day 2019-10-18 - Error 64.27856
# 2019-10-19
# Day 2019-10-19 - Error 29.58108
# 2019-10-20
# Day 2019-10-20 - Error 54.91058
# 2019-10-21
# Day 2019-10-21 - Error 29.06552
# 2019-10-22
# Day 2019-10-22 - Error 27.57558
# 2019-10-23
# Day 2019-10-23 - Error 38.31398
# 2019-10-24
# Day 2019-10-24 - Error 49.68431
# 2019-10-25
# Day 2019-10-25 - Error 104.78959
# 2019-10-26
# Day 2019-10-26 - Error 94.58200
# 2019-10-27
# Day 2019-10-27 - Error 51.31670
# 2019-10-28
# Day 2019-10-28 - Error 27.03998
# 2019-10-29
# Day 2019-10-29 - Error 51.12586
# 2019-10-30
# Day 2019-10-30 - Error 63.54248
# 2019-10-31
# Day 2019-10-31 - Error 39.56176
# 2019-11-01
# Day 2019-11-01 - Error 42.43063
# 2019-11-02
# Day 2019-11-02 - Error 40.31775
# 2019-11-03
# Day 2019-11-03 - Error 54.09566
# 2019-11-04
# Day 2019-11-04 - Error 41.66247
# 2019-11-05
# Day 2019-11-05 - Error 25.24648
# 2019-11-06
# Day 2019-11-06 - Error 26.21060
# 2019-11-07
# Day 2019-11-07 - Error 25.05828
# 2019-11-08
# Day 2019-11-08 - Error 46.03936
# 2019-11-09
# Day 2019-11-09 - Error 40.41439
# 2019-11-10
# Day 2019-11-10 - Error 40.16364
# 2019-11-11
# Day 2019-11-11 - Error 38.16732
# 2019-11-12
# Day 2019-11-12 - Error 21.52710
# 2019-11-13
# Day 2019-11-13 - Error 84.93009
# 2019-11-14
# Day 2019-11-14 - Error 60.16274
# 2019-11-15
# Day 2019-11-15 - Error 41.25624
# 2019-11-16
# Day 2019-11-16 - Error 76.84453
# 2019-11-17
# Day 2019-11-17 - Error 55.76029
# 2019-11-18
# Day 2019-11-18 - Error 34.67801
# 2019-11-19
# Day 2019-11-19 - Error 25.55325
# 2019-11-20
# Day 2019-11-20 - Error 29.28292
# 2019-11-21
# Day 2019-11-21 - Error 31.00829
# 2019-11-22
# Day 2019-11-22 - Error 45.45246
# 2019-11-23
# Day 2019-11-23 - Error 53.36068
# 2019-11-24
# Day 2019-11-24 - Error 47.17297
# 2019-11-25
# Day 2019-11-25 - Error 50.11269
# 2019-11-26
# Day 2019-11-26 - Error 76.73291
# 2019-11-27
# Day 2019-11-27 - Error 77.33297
# 2019-11-28
# Day 2019-11-28 - Error 80.08752
# 2019-11-29
# Day 2019-11-29 - Error 70.19980
# 2019-11-30
# Day 2019-11-30 - Error 40.84860
# 2019-12-01
# Day 2019-12-01 - Error 40.77837
# 2019-12-02
# Day 2019-12-02 - Error 37.84726
# 2019-12-03
# Day 2019-12-03 - Error 33.96146
# 2019-12-04
# Day 2019-12-04 - Error 32.83290
# 2019-12-05
# Day 2019-12-05 - Error 50.98044
# 2019-12-06
# Day 2019-12-06 - Error 359.24735
# 2019-12-07
# Day 2019-12-07 - Error 53.11771
# 2019-12-08
# Day 2019-12-08 - Error 40.02493
# 2019-12-09
# Day 2019-12-09 - Error 29.01053
# 2019-12-10
# Day 2019-12-10 - Error 25.55156
# 2019-12-11
# Day 2019-12-11 - Error 41.37026
# 2019-12-12
# Day 2019-12-12 - Error 27.45345
# 2019-12-13
# Day 2019-12-13 - Error 52.89862
# 2019-12-14
# Day 2019-12-14 - Error 47.48646
# 2019-12-15
# Day 2019-12-15 - Error 41.10814
# 2019-12-16
# Day 2019-12-16 - Error 64.72980
# 2019-12-17
# Day 2019-12-17 - Error 116.88460
# 2019-12-18
# Day 2019-12-18 - Error 33.75151
# 2019-12-19
# Day 2019-12-19 - Error 267.94305
# 2019-12-20
# Day 2019-12-20 - Error 82.51824
# 2019-12-21
# Day 2019-12-21 - Error 47.16361
# 2019-12-22
# Day 2019-12-22 - Error 94.11511
# 2019-12-23
# Day 2019-12-23 - Error 108.18786
# 2019-12-24
# Day 2019-12-24 - Error 69.22135
# 2019-12-25
# 2019-12-26
# Day 2019-12-26 - Error 60.82414
# 2019-12-27
# Day 2019-12-27 - Error 37.23241
# 2019-12-28
# Day 2019-12-28 - Error 51.15488
# 2019-12-29
# Day 2019-12-29 - Error 44.47361
# 2019-12-30
# Day 2019-12-30 - Error 43.94258
# 2019-12-31
# Day 2019-12-31 - Error 63.17984
# 2020-01-01
# Day 2020-01-01 - Error 78.09378
# 2020-01-02
# Day 2020-01-02 - Error 34.28855
# 2020-01-03
# Day 2020-01-03 - Error 41.85845
# 2020-01-04
# Day 2020-01-04 - Error 40.74202
# 2020-01-05
# Day 2020-01-05 - Error 55.25749
# 2020-01-06
# Day 2020-01-06 - Error 67.89707
# 2020-01-07
# Day 2020-01-07 - Error 35.53959
# 2020-01-08
# Day 2020-01-08 - Error 44.30929
# 2020-01-09
# Day 2020-01-09 - Error 39.86479
# 2020-01-10
# Day 2020-01-10 - Error 39.50277
# 2020-01-11
# Day 2020-01-11 - Error 88.16408
# 2020-01-12
# Day 2020-01-12 - Error 54.96100
# 2020-01-13
# Day 2020-01-13 - Error 37.65279
# 2020-01-14
# Day 2020-01-14 - Error 107.33837
# 2020-01-15
# Day 2020-01-15 - Error 49.90407
# 2020-01-16
# Day 2020-01-16 - Error 97.64546
# 2020-01-17
# Day 2020-01-17 - Error 36.94337
# 2020-01-18
# Day 2020-01-18 - Error 59.30485
# 2020-01-19
# Day 2020-01-19 - Error 87.00422
# 2020-01-20
# Day 2020-01-20 - Error 36.88522
# 2020-01-21
# Day 2020-01-21 - Error 23.36601
# 2020-01-22
# Day 2020-01-22 - Error 35.81669
# 2020-01-23
# Day 2020-01-23 - Error 102.60510
# 2020-01-24
# Day 2020-01-24 - Error 40.88900
# 2020-01-25
# Day 2020-01-25 - Error 33.37037
# 2020-01-26
# Day 2020-01-26 - Error 47.75550
# 2020-01-27
# Day 2020-01-27 - Error 38.99989
# 2020-01-28
# Day 2020-01-28 - Error 149.92373
# 2020-01-29
# Day 2020-01-29 - Error 21.58871
# 2020-01-30
# Day 2020-01-30 - Error 30.25688
# 2020-01-31
# Day 2020-01-31 - Error 41.97258
# 2020-02-01
# Day 2020-02-01 - Error 59.23596
# 2020-02-02
# Day 2020-02-02 - Error 46.44698
# 2020-02-03
# Day 2020-02-03 - Error 50.46743
# 2020-02-04
# Day 2020-02-04 - Error 28.38728
# 2020-02-05
# Day 2020-02-05 - Error 49.36721
# 2020-02-06
# Day 2020-02-06 - Error 23.15304
# 2020-02-07
# Day 2020-02-07 - Error 35.68815
# 2020-02-08
# Day 2020-02-08 - Error 42.96110
# 2020-02-09
# Day 2020-02-09 - Error 43.91451
# 2020-02-10
# Day 2020-02-10 - Error 27.96251
# 2020-02-11
# Day 2020-02-11 - Error 27.37713
# 2020-02-12
# Day 2020-02-12 - Error 51.00186
# 2020-02-13
# Day 2020-02-13 - Error 55.65671
# 2020-02-14
# Day 2020-02-14 - Error 63.94621
# 2020-02-15
# Day 2020-02-15 - Error 97.20333
# 2020-02-16
# Day 2020-02-16 - Error 86.88428
# 2020-02-17
# Day 2020-02-17 - Error 20.82028
# 2020-02-18
# Day 2020-02-18 - Error 20.18084
# 2020-02-19
# Day 2020-02-19 - Error 26.50906
# 2020-02-20
# Day 2020-02-20 - Error 43.08504
# 2020-02-21
# Day 2020-02-21 - Error 39.29761
# 2020-02-22
# Day 2020-02-22 - Error 43.36351
# 2020-02-23
# Day 2020-02-23 - Error 47.97855
# 2020-02-24
# Day 2020-02-24 - Error 76.25708
# 2020-02-25
# Day 2020-02-25 - Error 57.06321
# 2020-02-26
# Day 2020-02-26 - Error 37.75158
# 2020-02-27
# Day 2020-02-27 - Error 36.12089
# 2020-02-28
# Day 2020-02-28 - Error 38.06221
# 2020-02-29
# Day 2020-02-29 - Error 38.90505
# Mean Error = 54.91939

# %%
import datetime
pd.set_option('mode.chained_assignment',None)

start_date = datetime.date(2020,3,1)
end_date = datetime.date(2020,12,31)
delta = datetime.timedelta(days=1)
dateidx = start_date

while dateidx <= end_date:
    print(dateidx)
    val_lgbm = wegmansnew[wegmansnew['DATE_KEY'] == pd.Timestamp(dateidx)] 
    if val_lgbm.size > 0:
        xts_lgbm = val_lgbm[['CATCODES','Yesterday Sales','Week Ago Sales','isWeekend']]
        p_lgbm = mdl_lgbm.predict(xts_lgbm)
        val_lgbm.loc[:, 'Prediction'] = np.round(p_lgbm)
        wegmanspredlgbm = pd.concat([wegmanspredlgbm,val_lgbm])
    dateidx += delta
# Out:
# 2020-03-01
# 2020-03-02
# 2020-03-03
# 2020-03-04
# 2020-03-05
# 2020-03-06
# 2020-03-07
# 2020-03-08
# 2020-03-09
# 2020-03-10
# 2020-03-11
# 2020-03-12
# 2020-03-13
# 2020-03-14
# 2020-03-15
# 2020-03-16
# 2020-03-17
# 2020-03-18
# 2020-03-19
# 2020-03-20
# 2020-03-21
# 2020-03-22
# 2020-03-23
# 2020-03-24
# 2020-03-25
# 2020-03-26
# 2020-03-27
# 2020-03-28
# 2020-03-29
# 2020-03-30
# 2020-03-31
# 2020-04-01
# 2020-04-02
# 2020-04-03
# 2020-04-04
# 2020-04-05
# 2020-04-06
# 2020-04-07
# 2020-04-08
# 2020-04-09
# 2020-04-10
# 2020-04-11
# 2020-04-12
# 2020-04-13
# 2020-04-14
# 2020-04-15
# 2020-04-16
# 2020-04-17
# 2020-04-18
# 2020-04-19
# 2020-04-20
# 2020-04-21
# 2020-04-22
# 2020-04-23
# 2020-04-24
# 2020-04-25
# 2020-04-26
# 2020-04-27
# 2020-04-28
# 2020-04-29
# 2020-04-30
# 2020-05-01
# 2020-05-02
# 2020-05-03
# 2020-05-04
# 2020-05-05
# 2020-05-06
# 2020-05-07
# 2020-05-08
# 2020-05-09
# 2020-05-10
# 2020-05-11
# 2020-05-12
# 2020-05-13
# 2020-05-14
# 2020-05-15
# 2020-05-16
# 2020-05-17
# 2020-05-18
# 2020-05-19
# 2020-05-20
# 2020-05-21
# 2020-05-22
# 2020-05-23
# 2020-05-24
# 2020-05-25
# 2020-05-26
# 2020-05-27
# 2020-05-28
# 2020-05-29
# 2020-05-30
# 2020-05-31
# 2020-06-01
# 2020-06-02
# 2020-06-03
# 2020-06-04
# 2020-06-05
# 2020-06-06
# 2020-06-07
# 2020-06-08
# 2020-06-09
# 2020-06-10
# 2020-06-11
# 2020-06-12
# 2020-06-13
# 2020-06-14
# 2020-06-15
# 2020-06-16
# 2020-06-17
# 2020-06-18
# 2020-06-19
# 2020-06-20
# 2020-06-21
# 2020-06-22
# 2020-06-23
# 2020-06-24
# 2020-06-25
# 2020-06-26
# 2020-06-27
# 2020-06-28
# 2020-06-29
# 2020-06-30
# 2020-07-01
# 2020-07-02
# 2020-07-03
# 2020-07-04
# 2020-07-05
# 2020-07-06
# 2020-07-07
# 2020-07-08
# 2020-07-09
# 2020-07-10
# 2020-07-11
# 2020-07-12
# 2020-07-13
# 2020-07-14
# 2020-07-15
# 2020-07-16
# 2020-07-17
# 2020-07-18
# 2020-07-19
# 2020-07-20
# 2020-07-21
# 2020-07-22
# 2020-07-23
# 2020-07-24
# 2020-07-25
# 2020-07-26
# 2020-07-27
# 2020-07-28
# 2020-07-29
# 2020-07-30
# 2020-07-31
# 2020-08-01
# 2020-08-02
# 2020-08-03
# 2020-08-04
# 2020-08-05
# 2020-08-06
# 2020-08-07
# 2020-08-08
# 2020-08-09
# 2020-08-10
# 2020-08-11
# 2020-08-12
# 2020-08-13
# 2020-08-14
# 2020-08-15
# 2020-08-16
# 2020-08-17
# 2020-08-18
# 2020-08-19
# 2020-08-20
# 2020-08-21
# 2020-08-22
# 2020-08-23
# 2020-08-24
# 2020-08-25
# 2020-08-26
# 2020-08-27
# 2020-08-28
# 2020-08-29
# 2020-08-30
# 2020-08-31
# 2020-09-01
# 2020-09-02
# 2020-09-03
# 2020-09-04
# 2020-09-05
# 2020-09-06
# 2020-09-07
# 2020-09-08
# 2020-09-09
# 2020-09-10
# 2020-09-11
# 2020-09-12
# 2020-09-13
# 2020-09-14
# 2020-09-15
# 2020-09-16
# 2020-09-17
# 2020-09-18
# 2020-09-19
# 2020-09-20
# 2020-09-21
# 2020-09-22
# 2020-09-23
# 2020-09-24
# 2020-09-25
# 2020-09-26
# 2020-09-27
# 2020-09-28
# 2020-09-29
# 2020-09-30
# 2020-10-01
# 2020-10-02
# 2020-10-03
# 2020-10-04
# 2020-10-05
# 2020-10-06
# 2020-10-07
# 2020-10-08
# 2020-10-09
# 2020-10-10
# 2020-10-11
# 2020-10-12
# 2020-10-13
# 2020-10-14
# 2020-10-15
# 2020-10-16
# 2020-10-17
# 2020-10-18
# 2020-10-19
# 2020-10-20
# 2020-10-21
# 2020-10-22
# 2020-10-23
# 2020-10-24
# 2020-10-25
# 2020-10-26
# 2020-10-27
# 2020-10-28
# 2020-10-29
# 2020-10-30
# 2020-10-31
# 2020-11-01
# 2020-11-02
# 2020-11-03
# 2020-11-04
# 2020-11-05
# 2020-11-06
# 2020-11-07
# 2020-11-08
# 2020-11-09
# 2020-11-10
# 2020-11-11
# 2020-11-12
# 2020-11-13
# 2020-11-14
# 2020-11-15
# 2020-11-16
# 2020-11-17
# 2020-11-18
# 2020-11-19
# 2020-11-20
# 2020-11-21
# 2020-11-22
# 2020-11-23
# 2020-11-24
# 2020-11-25
# 2020-11-26
# 2020-11-27
# 2020-11-28
# 2020-11-29
# 2020-11-30
# 2020-12-01
# 2020-12-02
# 2020-12-03
# 2020-12-04
# 2020-12-05
# 2020-12-06
# 2020-12-07
# 2020-12-08
# 2020-12-09
# 2020-12-10
# 2020-12-11
# 2020-12-12
# 2020-12-13
# 2020-12-14
# 2020-12-15
# 2020-12-16
# 2020-12-17
# 2020-12-18
# 2020-12-19
# 2020-12-20
# 2020-12-21
# 2020-12-22
# 2020-12-23
# 2020-12-24
# 2020-12-25
# 2020-12-26
# 2020-12-27
# 2020-12-28
# 2020-12-29
# 2020-12-30
# 2020-12-31

# %%
wegmanspredlgbm.to_csv('2019and2020pred_30daywindow_lbgbm.csv')

# %% [markdown]
# ### Analysis Begins

# %%
wegmans_pre = wegmans[(wegmans['DATE_KEY'] >= '2019-01-06') & (wegmans['DATE_KEY'] <= '2020-02-29')]

# %%
wegmans_during = wegmans[(wegmans['DATE_KEY'] > '2020-02-29') & (wegmans['DATE_KEY'] <= '2020-12-31')]

# %%
wegmans_lgbmpre = wegmanspredlgbm[(wegmanspredlgbm['DATE_KEY'] >= '2019-01-06') & (wegmanspredlgbm['DATE_KEY'] <= '2020-02-29')]

# %%
wegmans_lgbmduring = wegmanspredlgbm[(wegmanspredlgbm['DATE_KEY'] >= '2019-01-06') & (wegmanspredlgbm['DATE_KEY'] <= '2020-02-29')]

# %%
wegmansnew_pre = wegmansnew[(wegmansnew['DATE_KEY'] >= '2019-01-06') & (wegmansnew['DATE_KEY'] <= '2020-02-29')]

# %%
wegmansnew_during = wegmansnew[(wegmansnew['DATE_KEY'] > '2020-02-29') & (wegmansnew['DATE_KEY'] <= '2020-12-31')]

# %%
wegmans
# Out:
#           DATE_KEY  CUSTOMER_ID  ITEM_NBR  UNITS  WEIGHT  SALES  HOUSEHOLD_ID  \
# 2998247 2019-01-06         5289    222267      1     0.0   1.43           445
# 309961  2019-01-06         4907    154472      1     0.0   2.51           774
# 309972  2019-01-06         4907    556328      1     0.0   5.04           774
# 629001  2019-01-06         3530    135451      1     0.0   5.76          3530
# 923481  2019-01-06         2295    556328      1     0.0   5.04          2295
# ...            ...          ...       ...    ...     ...    ...           ...
# 2689097 2020-12-31         1997     48147      1     0.0   6.47          1997
# 3919347 2020-12-31         1897     39305      1     0.0   8.63          1897
# 4909291 2020-12-31         2487     39292      1     0.0   8.63          2487
# 5016221 2020-12-31         5584     39290      1     0.0   8.63          2706
# 5105192 2020-12-31         3718     48147      1     0.0   6.47          3718
#
#          HOH_AGE  HH_INCOME  HH_CHILDREN  ...  month  year dayofweek week  \
# 2998247       39   125000.0            1  ...      1  2019         1    1
# 309961        50    75000.0            0  ...      1  2019         1    1
# 309972        50    75000.0            0  ...      1  2019         1    1
# 629001        63   100000.0            1  ...      1  2019         1    1
# 923481        30    40000.0            0  ...      1  2019         1    1
# ...          ...        ...          ...  ...    ...   ...       ...  ...
# 2689097       60   100000.0            0  ...     12  2020         5   52
# 3919347       73   100000.0            1  ...     12  2020         5   52
# 4909291       60   125000.0            2  ...     12  2020         5   52
# 5016221       81    75000.0            0  ...     12  2020         5   52
# 5105192       86        NaN            1  ...     12  2020         5   52
#
#         monthyear weekyear   PPU  WEGMANS_ORGANIC  WEGMANS_FAMPACK  IS_BULK
# 2998247   2019/01  2019/01  1.43                0                0        0
# 309961    2019/01  2019/01  2.51                0                0        0
# 309972    2019/01  2019/01  5.04                0                0        0
# 629001    2019/01  2019/01  5.76                0                0        0
# 923481    2019/01  2019/01  5.04                0                0        0
# ...           ...      ...   ...              ...              ...      ...
# 2689097   2020/12  2020/52  6.47                0                0        0
# 3919347   2020/12  2020/52  8.63                0                0        0
# 4909291   2020/12  2020/52  8.63                0                0        0
# 5016221   2020/12  2020/52  8.63                0                0        0
# 5105192   2020/12  2020/52  6.47                0                0        0
#
# [5618235 rows x 31 columns]

# %%
wegmansnew
# Out:
#          DATE_KEY  DEPARTMENT_NAME                CATEGORY_NAME  SALES  \
# 0      2019-01-06            ASIAN                    ASIAN HOT   1.43
# 1      2019-01-06            ASIAN               ASIAN PACKAGED  91.42
# 2      2019-01-06         BAKESHOP                       BAGELS  25.26
# 3      2019-01-06         BAKESHOP             BAKESHOP COOKIES  39.06
# 4      2019-01-06         BAKESHOP  BAKESHOP DISTRIBUTION ITEMS  56.65
# ...           ...              ...                          ...    ...
# 300640 2020-12-31            SUSHI           SKINNY ROLLS SUSHI   6.47
# 300641 2020-12-31            SUSHI                 VEGGIE SUSHI  16.52
# 300642 2020-12-31  ULTIMATE COFFEE                    BREAKFAST   6.46
# 300643 2020-12-31  ULTIMATE COFFEE                  COLD DRINKS   2.12
# 300644 2020-12-31   WBRAND & OTHER               W BRAND RETAIL  66.77
#
#         Yesterday Sales  Week Ago Sales  isWeekend  CATCODES
# 0                  0.00            0.00       True        14
# 1                  0.00            0.00       True        15
# 2                  0.00            0.00       True        23
# 3                  0.00            0.00       True        26
# 4                  0.00            0.00       True        27
# ...                 ...             ...        ...       ...
# 300640            12.94           11.50      False       488
# 300641            25.15           25.14      False       557
# 300642             3.23            3.23      False        52
# 300643             1.69            4.60      False       112
# 300644            53.39           76.43      False       563
#
# [300645 rows x 8 columns]

# %%
wegmanspredlgbm
# Out:
#          DATE_KEY  DEPARTMENT_NAME                CATEGORY_NAME  SALES  \
# 439    2019-01-07            ASIAN                    ASIAN HOT   1.43
# 440    2019-01-07            ASIAN               ASIAN PACKAGED  41.76
# 441    2019-01-07         BAKESHOP                       BAGELS  12.70
# 442    2019-01-07         BAKESHOP             BAKESHOP COOKIES  35.63
# 443    2019-01-07         BAKESHOP  BAKESHOP DISTRIBUTION ITEMS  19.35
# ...           ...              ...                          ...    ...
# 300640 2020-12-31            SUSHI           SKINNY ROLLS SUSHI   6.47
# 300641 2020-12-31            SUSHI                 VEGGIE SUSHI  16.52
# 300642 2020-12-31  ULTIMATE COFFEE                    BREAKFAST   6.46
# 300643 2020-12-31  ULTIMATE COFFEE                  COLD DRINKS   2.12
# 300644 2020-12-31   WBRAND & OTHER               W BRAND RETAIL  66.77
#
#         Yesterday Sales  Week Ago Sales  isWeekend  CATCODES  Prediction
# 439                1.43            0.00      False        14        37.0
# 440               91.42            0.00      False        15        37.0
# 441              117.27            0.00      False        23        37.0
# 442               39.06            0.00      False        26        28.0
# 443               56.65            0.00      False        27        28.0
# ...                 ...             ...        ...       ...         ...
# 300640            12.94           11.50      False       488         2.0
# 300641            25.15           25.14      False       557         3.0
# 300642             3.23            3.23      False        52         2.0
# 300643             1.69            4.60      False       112         2.0
# 300644            53.39           76.43      False       563         4.0
#
# [300206 rows x 9 columns]

# %%
x_wegmansdaypre = wegmans_pre['dayofweek'].value_counts(sort=False).index
y_wegmansdaypre = wegmans_pre['dayofweek'].value_counts(sort=False).values

x_wegmansdayduring = wegmans_during['dayofweek'].value_counts(sort=False).index
y_wegmansdayduring = wegmans_during['dayofweek'].value_counts(sort=False).values

fig = plt.figure(figsize = (10, 7))

width = 0.24

plt.bar(x_wegmansdaypre-.12, y_wegmansdaypre, width, color="orange")
plt.bar(x_wegmansdayduring+0.12, y_wegmansdayduring, width, color="green")

plt.xticks(x_wegmansdaypre,['Sunday','Monday','Tuesday','Wednesday','Thursday','Friday','Saturday'])
plt.title("Number of Transactions by Day of Week")
plt.legend(["Pre-Pandemic", "During Pandemic"])
plt.show()

# %%
x_wegmansmonthpre = wegmans_pre['month'].value_counts(sort=False).index
y_wegmansmonthpre = wegmans_pre['month'].value_counts(sort=False).values

x_wegmansmonthduring = wegmans_during['month'].value_counts(sort=False).index
y_wegmansmonthduring = wegmans_during['month'].value_counts(sort=False).values

fig = plt.figure(figsize = (10, 7))

width = 0.24

plt.bar(x_wegmansmonthpre-.12, y_wegmansmonthpre, width, color="orange")
plt.bar(x_wegmansmonthduring+0.12, y_wegmansmonthduring, width, color="green")

plt.title("Number of Transactions by Month")
plt.legend(["Pre-Pandemic", "During Pandemic"])
plt.show()

# %%
topsalespre_dept = wegmansnew_pre.groupby(['DEPARTMENT_NAME'], as_index=False).agg({"SALES": "sum"}).sort_values(('SALES'), ascending=False)

# %%
topsalesduring_dept = wegmansnew_during.groupby(['DEPARTMENT_NAME'], as_index=False).agg({"SALES": "sum"}).sort_values(('SALES'), ascending=False)

# %%
topsales_dept = pd.merge(topsalespre_dept, topsalesduring_dept, on='DEPARTMENT_NAME')

# %%
topsalespre_dept.head(8)
# Out:
#          DEPARTMENT_NAME       SALES
# 22               GROCERY  2890225.75
# 36               PRODUCE  1251625.10
# 30                  MEAT   812680.40
# 10                 DAIRY   665352.00
# 23  HEALTH & BEAUTY CARE   602118.37
# 34           PHARMACY RX   517348.55
# 16           FROZEN FOOD   406568.92
# 6     COLD CUTS & CHEESE   221297.74

# %%
topsalesduring_dept.head(8)
# Out:
#          DEPARTMENT_NAME       SALES
# 22               GROCERY  2247591.80
# 36               PRODUCE   941185.24
# 30                  MEAT   684533.04
# 10                 DAIRY   533869.47
# 23  HEALTH & BEAUTY CARE   439490.84
# 16           FROZEN FOOD   344286.58
# 2    BEER & WINE COOLERS   205471.53
# 6     COLD CUTS & CHEESE   181052.19

# %%
topsales_dept = topsales_dept[(topsales_dept["DEPARTMENT_NAME"] == 'GROCERY') |
             (topsales_dept["DEPARTMENT_NAME"] == 'PRODUCE') |
             (topsales_dept["DEPARTMENT_NAME"] == 'MEAT') |
             (topsales_dept["DEPARTMENT_NAME"] == 'DAIRY') |
             (topsales_dept["DEPARTMENT_NAME"] == 'HEALTH & BEAUTY CARE') |
             (topsales_dept["DEPARTMENT_NAME"] == 'PHARMACY RX') |
             (topsales_dept["DEPARTMENT_NAME"] == 'FROZEN FOOD') |
             (topsales_dept["DEPARTMENT_NAME"] == 'COLD CUT & CHEESE') |
             (topsales_dept["DEPARTMENT_NAME"] == 'BEER & WINE COOLERS')]

# %%
topsales_dept.head(8)
# Out:
#         DEPARTMENT_NAME     SALES_x     SALES_y
# 0               GROCERY  2890225.75  2247591.80
# 1               PRODUCE  1251625.10   941185.24
# 2                  MEAT   812680.40   684533.04
# 3                 DAIRY   665352.00   533869.47
# 4  HEALTH & BEAUTY CARE   602118.37   439490.84
# 5           PHARMACY RX   517348.55   119924.56
# 6           FROZEN FOOD   406568.92   344286.58
# 8   BEER & WINE COOLERS   219486.24   205471.53

# %%
topchangepre_dept = wegmansnew_pre.groupby(['DEPARTMENT_NAME'], as_index=False).agg({"SALES": "sum"})

# %%
topchangeduring_dept = wegmansnew_during.groupby(['DEPARTMENT_NAME'], as_index=False).agg({"SALES": "sum"})

# %%
topchange_dept = pd.merge(topchangepre_dept, topchangeduring_dept, on='DEPARTMENT_NAME')

# %%
topchange_dept['CHANGE_IN_SALES'] = ((topchange_dept['SALES_y']-topchange_dept['SALES_x'])/topchange_dept['SALES_x'])

# %%
topchange_dept.sort_values(('CHANGE_IN_SALES'), ascending=False)
# Out:
#                  DEPARTMENT_NAME     SALES_x     SALES_y  CHANGE_IN_SALES
# 40            SPECIAL PROMOTIONS        0.00       21.60              inf
# 12           DIGITAL FULFILLMENT      256.35      664.75         1.593134
# 18                FROZEN SEAFOOD    68782.33    65449.73        -0.048451
# 2            BEER & WINE COOLERS   219486.24   205471.53        -0.063852
# 15                 FRESH SEAFOOD   116746.09   108120.27        -0.073885
# 17                   FROZEN MEAT    34378.96    30717.29        -0.106509
# 11                DAIRY PRE-PACK    95944.18    82877.33        -0.136192
# 25                     ICE CREAM   132076.15   113525.01        -0.140458
# 16                   FROZEN FOOD   406568.92   344286.58        -0.153190
# 30                          MEAT   812680.40   684533.04        -0.157685
# 0                          ASIAN    25565.71    21273.64        -0.167884
# 29                       ITALIAN    16515.76    13709.86        -0.169892
# 6             COLD CUTS & CHEESE   221297.74   181052.19        -0.181862
# 32             OLDE WORLD CHEESE   142585.80   115910.63        -0.187082
# 31             OF SUBMARINE SHOP    94802.04    76367.74        -0.194450
# 10                         DAIRY   665352.00   533869.47        -0.197613
# 22                       GROCERY  2890225.75  2247591.80        -0.222347
# 1                       BAKESHOP   216177.28   166822.60        -0.228307
# 19  GM BASIC PRODUCTS DEPARTMENT   118058.59    90497.02        -0.233457
# 13                          EGGS    64171.27    48781.97        -0.239816
# 41                         SUSHI    71328.82    53810.14        -0.245605
# 36                       PRODUCE  1251625.10   941185.24        -0.248029
# 20      GM FOR FOOD (HOUSEWARES)    48856.89    36591.23        -0.251053
# 21       GM SEASONAL MERCHANDISE    26580.34    19854.66        -0.253032
# 23          HEALTH & BEAUTY CARE   602118.37   439490.84        -0.270092
# 9                 CULTURED DAIRY   202230.66   143299.22        -0.291407
# 27             IN-STORE DESSERTS   126749.58    89533.13        -0.293622
# 26        IN-STORE BREAD & ROLLS   100670.49    70805.59        -0.296660
# 28             INSTORE BREAKFAST    85044.98    59475.12        -0.300663
# 14                        FLORAL    78486.16    54398.62        -0.306902
# 37                READING CENTER    29035.30    19059.36        -0.343580
# 24            HOMESTYLE AMERICAN   100806.56    64267.93        -0.362463
# 5                CARD DEPARTMENT    74662.36    46160.75        -0.381740
# 4                     BULK FOODS    70937.68    43651.96        -0.384644
# 35                         PIZZA    81501.30    46896.46        -0.424592
# 39    SALADS, SANDWICHES & SOUPS    68422.62    38711.93        -0.434223
# 8                      COSMETICS    33545.48    16561.65        -0.506293
# 42               ULTIMATE COFFEE     7826.40     3548.40        -0.546611
# 33                  PHARMACY OTC      514.10      209.05        -0.593367
# 38                   RESTAURANTS     5917.50     1765.58        -0.701634
# 43                WBRAND & OTHER    87119.84    24570.84        -0.717965
# 34                   PHARMACY RX   517348.55   119924.56        -0.768194
# 3     BEVERAGE CONTAINER RETURNS        0.00        0.00              NaN
# 7      COMMUNITY RELATIONS ITEMS        0.00        0.00              NaN

# %%
topchange_dept = topchange_dept[(topchange_dept["DEPARTMENT_NAME"] == 'DIGITAL FULFILLMENT') |
             (topchange_dept["DEPARTMENT_NAME"] == 'PHARMACY RX') |
             (topchange_dept["DEPARTMENT_NAME"] == 'WBRAND & OTHER') |
             (topchange_dept["DEPARTMENT_NAME"] == 'RESTAURANTS') |
             (topchange_dept["DEPARTMENT_NAME"] == 'PHARMACY OTC') |
             (topchange_dept["DEPARTMENT_NAME"] == 'ULTIMATE COFFEE') |
             (topchange_dept["DEPARTMENT_NAME"] == 'COSMETICS') |
             (topchange_dept["DEPARTMENT_NAME"] == 'GROCERY') |
             (topchange_dept["DEPARTMENT_NAME"] == 'PRODUCE') |
            (topchange_dept["DEPARTMENT_NAME"] == 'HEALTH & BEAUTY CARE') ]

# %%
topchange_dept.sort_values(('CHANGE_IN_SALES'),ascending=False)
# Out:
#          DEPARTMENT_NAME     SALES_x     SALES_y  CHANGE_IN_SALES
# 12   DIGITAL FULFILLMENT      256.35      664.75         1.593134
# 22               GROCERY  2890225.75  2247591.80        -0.222347
# 36               PRODUCE  1251625.10   941185.24        -0.248029
# 23  HEALTH & BEAUTY CARE   602118.37   439490.84        -0.270092
# 8              COSMETICS    33545.48    16561.65        -0.506293
# 42       ULTIMATE COFFEE     7826.40     3548.40        -0.546611
# 33          PHARMACY OTC      514.10      209.05        -0.593367
# 38           RESTAURANTS     5917.50     1765.58        -0.701634
# 43        WBRAND & OTHER    87119.84    24570.84        -0.717965
# 34           PHARMACY RX   517348.55   119924.56        -0.768194

# %%
wegmanspred["DATE_KEY"] =  pd.to_datetime(wegmanspred["DATE_KEY"])
x_date = wegmanspred['DATE_KEY'].value_counts().index
y = wegmanspred.loc[wegmanspred.CATEGORY_NAME=='HOUSEHOLD CLEANERS'].groupby(['DATE_KEY']).agg({'Prediction': ['sum']})


plt.figure(figsize=(20, 5))
plt.scatter(x_date,y)

plt.title("Prediction Sales by Household Cleaners Category over Time")

plt.xlabel("Date (Year and Month)")
plt.ylabel("Average Last Week Sales")
plt.show()

# %%
wegmanspred["DATE_KEY"] =  pd.to_datetime(wegmanspred["DATE_KEY"])
x_date = wegmanspred['DATE_KEY'].value_counts().index
y = wegmanspred.loc[wegmanspred.CATEGORY_NAME=='HOUSEHOLD CLEANERS'].groupby(['DATE_KEY']).agg({'SALES': ['mean']})


plt.figure(figsize=(20, 5))
plt.scatter(x_date,y)

plt.title("Actual Sales by Household Cleaners Category over Time")

plt.xlabel("Date (Year and Month)")
plt.ylabel("Sales")
plt.show()
