# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px

# %%
mydir = "/Users/ptienpasertkij/Documents/RIT/Summer 2021/BANA785/All Data Files/"
wegmansLGBMData = mydir + "2019and2020pred_30daywindow_lgbm.csv"
wegmansLGBM = pd.read_csv(wegmansLGBMData)

# %%
wegmansLGBM
# Out:
#         Unnamed: 0    DATE_KEY  DEPARTMENT_NAME                CATEGORY_NAME  \
# 0              439  2019-01-07            ASIAN                    ASIAN HOT
# 1              440  2019-01-07            ASIAN               ASIAN PACKAGED
# 2              441  2019-01-07         BAKESHOP                       BAGELS
# 3              442  2019-01-07         BAKESHOP             BAKESHOP COOKIES
# 4              443  2019-01-07         BAKESHOP  BAKESHOP DISTRIBUTION ITEMS
# ...            ...         ...              ...                          ...
# 300201      300640  2020-12-31            SUSHI           SKINNY ROLLS SUSHI
# 300202      300641  2020-12-31            SUSHI                 VEGGIE SUSHI
# 300203      300642  2020-12-31  ULTIMATE COFFEE                    BREAKFAST
# 300204      300643  2020-12-31  ULTIMATE COFFEE                  COLD DRINKS
# 300205      300644  2020-12-31   WBRAND & OTHER               W BRAND RETAIL
#
#         SALES  Yesterday Sales  Week Ago Sales  isWeekend  CATCODES  \
# 0        1.43             1.43            0.00      False        14
# 1       41.76            91.42            0.00      False        15
# 2       12.70           117.27            0.00      False        23
# 3       35.63            39.06            0.00      False        26
# 4       19.35            56.65            0.00      False        27
# ...       ...              ...             ...        ...       ...
# 300201   6.47            12.94           11.50      False       488
# 300202  16.52            25.15           25.14      False       557
# 300203   6.46             3.23            3.23      False        52
# 300204   2.12             1.69            4.60      False       112
# 300205  66.77            53.39           76.43      False       563
#
#         Prediction
# 0             37.0
# 1             37.0
# 2             37.0
# 3             28.0
# 4             28.0
# ...            ...
# 300201         2.0
# 300202         3.0
# 300203         2.0
# 300204         2.0
# 300205         4.0
#
# [300206 rows x 10 columns]

# %%
wegmansLGBM["DATE_KEY"] =  pd.to_datetime(wegmansLGBM["DATE_KEY"])
x_date = wegmansLGBM['DATE_KEY']
y = wegmansLGBM['SALES']

x_datepred = wegmansLGBM['DATE_KEY']
y_pred = wegmansLGBM['Prediction']

plt.figure(figsize=(25, 10))
plt.scatter(x_date,y)
plt.scatter(x_datepred,y_pred)

plt.title("LGBM Prediction vs. Actual Sales over Time")

plt.xlabel("Date (Year and Month)")
plt.ylabel("Average Prediction")

plt.legend(["Actual Sales", "LGBM Predictions"])

plt.show()

# %%
wegmansLGBM_digital = wegmansLGBM[(wegmansLGBM["DEPARTMENT_NAME"] == 'DIGITAL FULFILLMENT')]

# %%
x_date = wegmansLGBM_digital['DATE_KEY']
y = wegmansLGBM_digital['SALES']

x_datepred = wegmansLGBM_digital.loc[wegmansLGBM.DATE_KEY >= '3/1/2020']['DATE_KEY']
y_pred = wegmansLGBM_digital.loc[wegmansLGBM.DATE_KEY >= '3/1/2020']['Prediction']

plt.figure(figsize=(25, 10))
plt.scatter(x_date,y)
plt.scatter(x_datepred,y_pred)

plt.title("LGBM Prediction vs. Actual Sales over Time")

plt.xlabel("Date (Year and Month)")
plt.ylabel("Average Prediction")

plt.legend(["Actual Sales", "LGBM Predictions"])

plt.show()

# %%
wegmansLGBM_rx = wegmansLGBM[(wegmansLGBM["DEPARTMENT_NAME"] == 'PHARMACY RX')]

# %%
x_date = wegmansLGBM_rx['DATE_KEY']
y = wegmansLGBM_rx['SALES']

x_datepred_rx = wegmansLGBM_rx['DATE_KEY']
y_pred_rx = wegmansLGBM_rx['Prediction']

plt.figure(figsize=(25, 10))
plt.scatter(x_date,y)
plt.scatter(x_datepred_rx,y_pred_rx)

plt.title("LGBM Prediction vs. Actual Sales over Time")

plt.xlabel("Date (Year and Month)")
plt.ylabel("Average Prediction")

plt.legend(["Actual Sales", "LGBM Predictions"])

plt.show()

# %%
wegmansLGBM_wegmansbrand = wegmansLGBM[(wegmansLGBM["DEPARTMENT_NAME"] == 'WBRAND & OTHER')]

# %%
x_date = wegmansLGBM_wegmansbrand['DATE_KEY']
y = wegmansLGBM_wegmansbrand['SALES']

x_datepred = wegmansLGBM_wegmansbrand.loc[wegmansLGBM_wegmansbrand.DATE_KEY >= '3/1/2020']['DATE_KEY']
y_pred = wegmansLGBM_wegmansbrand.loc[wegmansLGBM_wegmansbrand.DATE_KEY >= '3/1/2020']['Prediction']

plt.figure(figsize=(25, 10))
plt.scatter(x_date,y)
plt.scatter(x_datepred,y_pred)

plt.title("LGBM Prediction vs. Actual Sales over Time")

plt.xlabel("Date (Year and Month)")
plt.ylabel("Average Prediction")

plt.legend(["Actual Sales", "LGBM Predictions"])

plt.show()

# %%
wegmansLGBM['Prediction']
# Out:
# 0         37.0
# 1         37.0
# 2         37.0
# 3         28.0
# 4         28.0
#           ...
# 300201     2.0
# 300202     3.0
# 300203     2.0
# 300204     2.0
# 300205     4.0
# Name: Prediction, Length: 300206, dtype: float64

# %%
prediction
# Out:
# Index(['Unnamed: 0', 'DATE_KEY', 'DEPARTMENT_NAME', 'CATEGORY_NAME', 'SALES',
#        'Yesterday Sales', 'Week Ago Sales', 'sWeek', 'CATCODES', ''],
#       dtype='object')

# %%
wegmansLGBM.groupby('DATE_KEY')['Prediction'].mean()
# Out:
# DATE_KEY
# 2019-01-07    35.307692
# 2019-01-08    30.487437
# 2019-01-09    28.190594
# 2019-01-10    39.148936
# 2019-01-11    27.124706
#                 ...
# 2020-12-27     3.530713
# 2020-12-28     3.417284
# 2020-12-29     3.260563
# 2020-12-30     3.296380
# 2020-12-31     3.533632
# Name: Prediction, Length: 723, dtype: float64

# %%
wegmansLGBM["DATE_KEY"] =  pd.to_datetime(wegmansLGBM["DATE_KEY"])
x_date = wegmansLGBM['DATE_KEY'].value_counts().index
y = wegmansLGBM.groupby('DATE_KEY')['SALES'].mean()

x_datepred = wegmansLGBM['DATE_KEY'].value_counts().index
y_pred = wegmansLGBM.groupby('DATE_KEY')['Prediction'].value()

plt.figure(figsize=(25, 10))
plt.scatter(x_date,y)
plt.scatter(x_datepred,y_pred)

plt.title("LGBM Prediction vs. Actual Sales over Time")

plt.xlabel("Date (Year and Month)")
plt.ylabel("Average Prediction")

plt.legend(["Actual Sales", "LGBM Predictions"])

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-17470a0ce043> in <module>
#       4
#       5 x_datepred = wegmansLGBM['DATE_KEY'].value_counts().index
# ----> 6 y_pred = wegmansLGBM.groupby('DATE_KEY')['Prediction'].value()
#       7
#       8 plt.figure(figsize=(25, 10))
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in __getattr__(self, attr)
#     701             return self[attr]
#     702
# --> 703         raise AttributeError(
#     704             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     705         )
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'value'

# %%
wegmansLGBM.head(50)
# Out:
#     Unnamed: 0   DATE_KEY             DEPARTMENT_NAME  \
# 0          439 2019-01-07                       ASIAN
# 1          440 2019-01-07                       ASIAN
# 2          441 2019-01-07                    BAKESHOP
# 3          442 2019-01-07                    BAKESHOP
# 4          443 2019-01-07                    BAKESHOP
# 5          444 2019-01-07                    BAKESHOP
# 6          445 2019-01-07                    BAKESHOP
# 7          446 2019-01-07                    BAKESHOP
# 8          447 2019-01-07                    BAKESHOP
# 9          448 2019-01-07                    BAKESHOP
# 10         449 2019-01-07                    BAKESHOP
# 11         450 2019-01-07                    BAKESHOP
# 12         451 2019-01-07                    BAKESHOP
# 13         452 2019-01-07                    BAKESHOP
# 14         453 2019-01-07                    BAKESHOP
# 15         454 2019-01-07                    BAKESHOP
# 16         455 2019-01-07         BEER & WINE COOLERS
# 17         456 2019-01-07         BEER & WINE COOLERS
# 18         457 2019-01-07         BEER & WINE COOLERS
# 19         458 2019-01-07         BEER & WINE COOLERS
# 20         459 2019-01-07         BEER & WINE COOLERS
# 21         460 2019-01-07         BEER & WINE COOLERS
# 22         461 2019-01-07         BEER & WINE COOLERS
# 23         462 2019-01-07  BEVERAGE CONTAINER RETURNS
# 24         463 2019-01-07  BEVERAGE CONTAINER RETURNS
# 25         464 2019-01-07                  BULK FOODS
# 26         465 2019-01-07                  BULK FOODS
# 27         466 2019-01-07                  BULK FOODS
# 28         467 2019-01-07                  BULK FOODS
# 29         468 2019-01-07                  BULK FOODS
# 30         469 2019-01-07                  BULK FOODS
# 31         470 2019-01-07                  BULK FOODS
# 32         471 2019-01-07                  BULK FOODS
# 33         472 2019-01-07                  BULK FOODS
# 34         473 2019-01-07                  BULK FOODS
# 35         474 2019-01-07                  BULK FOODS
# 36         475 2019-01-07                  BULK FOODS
# 37         476 2019-01-07                  BULK FOODS
# 38         477 2019-01-07                  BULK FOODS
# 39         478 2019-01-07                  BULK FOODS
# 40         479 2019-01-07                  BULK FOODS
# 41         480 2019-01-07             CARD DEPARTMENT
# 42         481 2019-01-07             CARD DEPARTMENT
# 43         482 2019-01-07             CARD DEPARTMENT
# 44         483 2019-01-07          COLD CUTS & CHEESE
# 45         484 2019-01-07          COLD CUTS & CHEESE
# 46         485 2019-01-07          COLD CUTS & CHEESE
# 47         486 2019-01-07          COLD CUTS & CHEESE
# 48         487 2019-01-07          COLD CUTS & CHEESE
# 49         488 2019-01-07          COLD CUTS & CHEESE
#
#                      CATEGORY_NAME   SALES  Yesterday Sales  Week Ago Sales  \
# 0                        ASIAN HOT    1.43             1.43             0.0
# 1                   ASIAN PACKAGED   41.76            91.42             0.0
# 2                           BAGELS   12.70           117.27             0.0
# 3                 BAKESHOP COOKIES   35.63            39.06             0.0
# 4      BAKESHOP DISTRIBUTION ITEMS   19.35            56.65             0.0
# 5                         BROWNIES    6.12             7.74             0.0
# 6                      GLUTEN FREE    4.31            12.79             0.0
# 7           KOSHER BAKERY PRODUCTS    4.31             4.31             0.0
# 8   MISCELLANEOUS COMMERCIAL BAKER    8.62            17.41             0.0
# 9                   ORGANIC BREADS    8.64            48.96             0.0
# 10       PITAS, FLATBREADS & WRAPS   28.68           106.92             0.0
# 11                           ROLLS   36.23            48.58             0.0
# 12       SPECIAL DIET BAKERY ITEMS    3.95             3.95             0.0
# 13                  VARIETY BREADS  152.05           249.95             0.0
# 14    VENDOR ENG MUFFINS & WAFFLES   40.70            62.76             0.0
# 15                    WHITE BREADS   21.47            24.27             0.0
# 16                          CIDERS   33.08            53.21             0.0
# 17                      CRAFT BEER  119.38           165.76             0.0
# 18             CRAFT YOUR OWN PACK    7.91             7.91             0.0
# 19                    HARD SELTZER   21.59             0.00             0.0
# 20                   IMPORTED BEER   34.52            69.03             0.0
# 21                    PREMIUM BEER   26.61            99.98             0.0
# 22                      VALUE BEER   12.08            36.67             0.0
# 23     BEVERAGE CONTAINER DEPOSITS    0.00             0.00             0.0
# 24       BEVERAGE CONTAINER RETURN    0.00             0.00             0.0
# 25                BAKING & COOKING    0.47             7.38             0.0
# 26                 BULK SNACK NUTS   25.12            58.53             0.0
# 27                       BULK TUBS   10.06            41.67             0.0
# 28                           CANDY   22.53            15.04             0.0
# 29                          CEREAL    5.27             1.96             0.0
# 30                      CHOCOLATES   12.56            15.48             0.0
# 31            COOKIES AND CRACKERS    0.95             0.00             0.0
# 32              DISCONTINUED ITEMS   14.38             0.00             0.0
# 33                     DRIED FRUIT   30.85            10.50             0.0
# 34                LUNCH BOX SNACKS    0.36             1.08             0.0
# 35             PACKAGED SNACK NUTS    3.59             0.00             0.0
# 36                        PET FOOD    0.71             5.16             0.0
# 37                     SNACK MIXES    7.21             4.51             0.0
# 38                  SPICES & HERBS    1.43             1.79             0.0
# 39                  TRAIL MIX BARS    4.03             2.82             0.0
# 40                      VALENTINES    7.09            18.67             0.0
# 41             CARD SHOP GIFT WRAP    2.87             3.59             0.0
# 42        CARD SHOP PARTY SUPPLIES    3.20             0.00             0.0
# 43                  GREETING CARDS   40.86           133.97             0.0
# 44                            BEEF   25.95           526.84             0.0
# 45                     CHARCUTERIE   55.29            74.04             0.0
# 46                          CHEESE   99.84           135.82             0.0
# 47         CHICKEN & MISC. POULTRY   17.39            42.46             0.0
# 48                             HAM   98.21           190.57             0.0
# 49                 KOSHER DELI-RTG    2.01             9.73             0.0
#
#     isWeekend  CATCODES  Prediction
# 0       False        14        37.0
# 1       False        15        37.0
# 2       False        23        37.0
# 3       False        26        28.0
# 4       False        27        28.0
# 5       False        56        25.0
# 6       False       234        12.0
# 7       False       310        10.0
# 8       False       349        14.0
# 9       False       373        52.0
# 10      False       410        43.0
# 11      False       441        44.0
# 12      False       506        25.0
# 13      False       552        22.0
# 14      False       559        31.0
# 15      False       571        31.0
# 16      False        99        40.0
# 17      False       134        62.0
# 18      False       136        24.0
# 19      False       256        29.0
# 20      False       284        15.0
# 21      False       420        66.0
# 22      False       550        22.0
# 23      False        41        18.0
# 24      False        42        18.0
# 25      False        29        28.0
# 26      False        58        34.0
# 27      False        59        34.0
# 28      False        67        30.0
# 29      False        87        16.0
# 30      False        96        43.0
# 31      False       121        62.0
# 32      False       152        33.0
# 33      False       162        33.0
# 34      False       327        29.0
# 35      False       380        62.0
# 36      False       398        35.0
# 37      False       495        29.0
# 38      False       511        11.0
# 39      False       539        29.0
# 40      False       548        30.0
# 41      False        75        37.0
# 42      False        77        37.0
# 43      False       243        33.0
# 44      False        39        56.0
# 45      False        88        16.0
# 46      False        90        43.0
# 47      False        93        44.0
# 48      False       251        36.0
# 49      False       313        10.0

# %%
wegmansLGBM[wegmansLGBM['DATE_KEY'] >= '3/1/2020']
# Out:
#         Unnamed: 0   DATE_KEY  DEPARTMENT_NAME                CATEGORY_NAME  \
# 175022      175461 2020-03-01            ASIAN               ASIAN PACKAGED
# 175023      175462 2020-03-01         BAKESHOP                       BAGELS
# 175024      175463 2020-03-01         BAKESHOP             BAKESHOP COOKIES
# 175025      175464 2020-03-01         BAKESHOP  BAKESHOP DISTRIBUTION ITEMS
# 175026      175465 2020-03-01         BAKESHOP                     BROWNIES
# ...            ...        ...              ...                          ...
# 300201      300640 2020-12-31            SUSHI           SKINNY ROLLS SUSHI
# 300202      300641 2020-12-31            SUSHI                 VEGGIE SUSHI
# 300203      300642 2020-12-31  ULTIMATE COFFEE                    BREAKFAST
# 300204      300643 2020-12-31  ULTIMATE COFFEE                  COLD DRINKS
# 300205      300644 2020-12-31   WBRAND & OTHER               W BRAND RETAIL
#
#         SALES  Yesterday Sales  Week Ago Sales  isWeekend  CATCODES  \
# 175022  52.56            16.56           49.50       True        15
# 175023  19.53            65.01            2.15       True        23
# 175024  64.80            51.30           46.80       True        26
# 175025  35.85            34.40           40.15       True        27
# 175026  16.02            11.88            6.66       True        56
# ...       ...              ...             ...        ...       ...
# 300201   6.47            12.94           11.50      False       488
# 300202  16.52            25.15           25.14      False       557
# 300203   6.46             3.23            3.23      False        52
# 300204   2.12             1.69            4.60      False       112
# 300205  66.77            53.39           76.43      False       563
#
#         Prediction
# 175022         3.0
# 175023         3.0
# 175024         4.0
# 175025         4.0
# 175026         3.0
# ...            ...
# 300201         2.0
# 300202         3.0
# 300203         2.0
# 300204         2.0
# 300205         4.0
#
# [125184 rows x 10 columns]
